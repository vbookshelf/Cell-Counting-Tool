# %%
# set seeds to ensure repeatability of results
from numpy.random import seed
seed(101)
from tensorflow import set_random_seed
set_random_seed(101)

import pandas as pd
import numpy as np
import os
import cv2

import tensorflow 

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, Flatten, ZeroPadding2D
from tensorflow.keras.layers import BatchNormalization, LeakyReLU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.metrics import binary_accuracy

import matplotlib.pyplot as plt
# %matplotlib inline

from skimage.io import imread, imshow
from skimage.transform import resize


# Don't Show Warning Messages
import warnings
warnings.filterwarnings('ignore')

# %%
IMG_HEIGHT = 128
IMG_WIDTH = 128
IMG_CHANNELS = 3

PADDING = 40

NUM_TEST_IMAGES = 10

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this kernel our goal is to build a computer vision model that can look at a mask of a micropscope slide and predict how many cells are present.
#
# This is a link to a web interface where a similar model has been deployed. You can submit jpg mask images and get an automatic cell count. Please use the Chrome browser for best results.<br>
# http://cellcount.test.woza.work/
#
# This site can be used to convert images from TIF to jpg format.<br>
# https://tiff2jpg.com/

# %%
# ==============================    
# Make a List of Test Set Masks
# ==============================

test_id_list = ['SIMCEPImages_A15_C61_F1_s03_w2.TIF',
 'SIMCEPImages_A21_C87_F1_s03_w1.TIF',
 'SIMCEPImages_A01_C1_F1_s02_w1.TIF',
 'SIMCEPImages_A04_C14_F1_s05_w1.TIF',
 'SIMCEPImages_A18_C74_F1_s01_w1.TIF',
 'SIMCEPImages_A04_C14_F1_s18_w1.TIF',
 'SIMCEPImages_A18_C74_F1_s09_w2.TIF',
 'SIMCEPImages_A13_C53_F1_s10_w2.TIF',
 'SIMCEPImages_A08_C31_F1_s13_w2.TIF',
 'SIMCEPImages_A19_C78_F1_s15_w2.TIF']

num_cells = [61, 87, 1, 14, 74, 14, 74, 53, 31, 78]


# =====================    
# Create X_test
# ===================== 

# create an empty matrix
X_test = np.zeros((len(test_id_list), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)) #, dtype=np.bool)


for i, mask_id in enumerate(test_id_list):
    
    path_mask = '../input/bbbc005_v1_ground_truth/BBBC005_v1_ground_truth/' + mask_id
    
    # read the file as an array
    cv2_image = cv2.imread(path_mask)
    # resize the image
    cv2_image = cv2.resize(cv2_image, (IMG_HEIGHT, IMG_WIDTH))
    # save the image at the destination as a jpg file
    cv2.imwrite('mask.jpg', cv2_image)

    
    # read the image using skimage
    mask = imread('mask.jpg')

    
    # resize the image
    #mask = resize(mask, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    
    # use np.expand dims to add a channel axis so the shape becomes (IMG_HEIGHT, IMG_WIDTH, 1)
    #mask = np.expand_dims(mask, axis=-1)
    
    # insert the image into X_Train
    X_test[i] = mask

    
    
# =====================    
# Display the masks
# =====================  

# set up the canvas for the subplots
plt.figure(figsize=(10,10))
plt.axis('Off')

# Our subplot will contain 3 rows and 3 columns
# plt.subplot(nrows, ncols, plot_number)


# == row 1 ==

# image
plt.subplot(3,3,1)
test_image = X_test[1, :, :, 0]
plt.imshow(test_image)
plt.title('Num Cells: 87', fontsize=14)
plt.axis('off')

# image
plt.subplot(3,3,2)
test_image = X_test[2, :, :, 0]
plt.imshow(test_image)
plt.title('Num Cells: 1', fontsize=14)
plt.axis('off')


# image
plt.subplot(3,3,3)
test_image = X_test[3, :, :, 0]
plt.imshow(test_image)
plt.title('Num Cells: 14', fontsize=14)
plt.axis('off')


# == row 2 ==

# image
plt.subplot(3,3,4)
test_image = X_test[4, :, :, 0]
plt.imshow(test_image)
plt.title('Num Cells: 74', fontsize=14)
plt.axis('off')

# image
plt.subplot(3,3,5)
test_image = X_test[5, :, :, 0]
plt.imshow(test_image)
plt.title('Num Cells: 14', fontsize=14)
plt.axis('off')

# image
plt.subplot(3,3,6)
test_image = X_test[6, :, :, 0]
plt.imshow(test_image)
plt.title('Num Cells: 74', fontsize=14)
plt.axis('off')


# == row 3 ==

# image
plt.subplot(3,3,7)
test_image = X_test[7, :, :, 0]
plt.imshow(test_image)
plt.title('Num Cells: 53', fontsize=14)
plt.axis('off')

# image
plt.subplot(3,3,8)
test_image = X_test[8, :, :, 0]
plt.imshow(test_image)
plt.title('Num Cells: 31', fontsize=14)
plt.axis('off')


# image
plt.subplot(3,3,9)
test_image = X_test[9, :, :, 0]
plt.imshow(test_image)
plt.title('Num Cells: 78', fontsize=14)
plt.axis('off')


plt.tight_layout()
plt.show()

# %% [markdown]
# These are 9 masks from the test set that we will be using in this kernel. As you can see some masks look like paint splashes. Even a human would find it difficult to predict how many cells are present. In fact cell counting requires a highly skilled microscopicist. As you can imagine, this work takes a long time. With only 1,190 training images, would it be possible to build a model that can automatically process these paint splashes and produce good results? Let's find out.

# %% [markdown]
# <hr>

# %% [markdown]
# ## Put all info into a dataframe

# %%
# get a list of files in each folder

img_list = os.listdir('../input/bbbc005_v1_images/BBBC005_v1_images')
mask_list = os.listdir('../input/bbbc005_v1_ground_truth/BBBC005_v1_ground_truth')

# create a dataframe
df_images = pd.DataFrame(img_list, columns=['image_id'])

# filter out the non image file that's called .htaccess
df_images = df_images[df_images['image_id'] != '.htaccess']



# Example file name: SIMCEPImages_A13_C53_F1_s23_w2.TIF


# ======================================================
# Add a column showing how many cells are on each image
# ======================================================

def get_num_cells(x):
    # split on the _
    a = x.split('_')
    # choose the third item
    b = a[2] # e.g. C53
    # choose second item onwards and convert to int
    num_cells = int(b[1:])
    
    return num_cells

# create a new column called 'num_cells'
df_images['num_cells'] = df_images['image_id'].apply(get_num_cells)


# ================================================
# Add a column indicating if an image has a mask.
# ================================================

# Keep in mind images and masks have the same file names.

def check_for_mask(x):
    if x in mask_list:
        return 'yes'
    else:
        return 'no'
    
# create a new column called 'has_mask'
df_images['has_mask'] = df_images['image_id'].apply(check_for_mask)



# ===========================================================
# Add a column showing how much blur was added to each image
# ===========================================================

def get_blur_amt(x):
    # split on the _
    a = x.split('_')
    # choose the third item
    b = a[3] # e.g. F1
    # choose second item onwards and convert to int
    blur_amt = int(b[1:])
    
    return blur_amt

# create a new column called 'blur_amt'
df_images['blur_amt'] = df_images['image_id'].apply(get_blur_amt)

# %%
df_images.head()
# Out:
#                               image_id  num_cells has_mask  blur_amt
# 0   SIMCEPImages_B17_C70_F4_s17_w2.TIF         70       no         4
# 1  SIMCEPImages_P20_C83_F48_s15_w1.TIF         83       no        48
# 2  SIMCEPImages_O16_C66_F45_s02_w2.TIF         66       no        45
# 3   SIMCEPImages_H02_C5_F23_s22_w1.TIF          5       no        23
# 4   SIMCEPImages_A06_C23_F1_s11_w2.TIF         23      yes         1

# %% [markdown]
# ## Create a df containing only masks

# %%
df_masks = df_images[df_images['has_mask'] == 'yes']

# create a new column called mask_id that is just a copy of image_id
df_masks['mask_id'] = df_masks['image_id']

df_masks.shape
# Out:
# (1200, 5)

# %%
df_masks.head()
# Out:
#                               image_id                 ...                                             mask_id
# 4   SIMCEPImages_A06_C23_F1_s11_w2.TIF                 ...                  SIMCEPImages_A06_C23_F1_s11_w2.TIF
# 12  SIMCEPImages_A12_C48_F1_s23_w1.TIF                 ...                  SIMCEPImages_A12_C48_F1_s23_w1.TIF
# 26  SIMCEPImages_A18_C74_F1_s09_w2.TIF                 ...                  SIMCEPImages_A18_C74_F1_s09_w2.TIF
# 59  SIMCEPImages_A15_C61_F1_s07_w1.TIF                 ...                  SIMCEPImages_A15_C61_F1_s07_w1.TIF
# 68  SIMCEPImages_A21_C87_F1_s07_w2.TIF                 ...                  SIMCEPImages_A21_C87_F1_s07_w2.TIF
#
# [5 rows x 5 columns]

# %% [markdown]
# ## Create df_test

# %%
# test_id_list and num_cells were defined in the introduction section.
df_test = pd.DataFrame(test_id_list, columns=['mask_id'])

# add a new column with the number of cells on each mask
df_test['num_cells'] = num_cells

# Reset the index.
# This is so that we can use loc to access mask id's later.
df_test = df_test.reset_index(drop=True)


# Select only rows that are not part of the test set.
# Note the use of ~ to execute 'not in'.
df_masks = df_masks[~df_masks['mask_id'].isin(test_id_list)]

print(df_masks.shape)
print(df_test.shape)
# Out:
# (1190, 5)
# (10, 2)

# %%
df_test.head()
# Out:
#                               mask_id  num_cells
# 0  SIMCEPImages_A15_C61_F1_s03_w2.TIF         61
# 1  SIMCEPImages_A21_C87_F1_s03_w1.TIF         87
# 2   SIMCEPImages_A01_C1_F1_s02_w1.TIF          1
# 3  SIMCEPImages_A04_C14_F1_s05_w1.TIF         14
# 4  SIMCEPImages_A18_C74_F1_s01_w1.TIF         74

# %% [markdown]
# ## Define X_train and y_train

# %%
# X_train

# Get lists of images and their masks.
mask_id_list = list(df_masks['mask_id'])

# Create empty arrays
X_train = np.zeros((len(mask_id_list), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)) #, dtype=np.bool)


for i, mask_id in enumerate(mask_id_list):
    
    path_mask = '../input/bbbc005_v1_ground_truth/BBBC005_v1_ground_truth/' + mask_id
    
    # read the file as an array
    cv2_image = cv2.imread(path_mask)
    # resize the image
    cv2_image = cv2.resize(cv2_image, (IMG_HEIGHT, IMG_WIDTH))
    # save the image at the destination as a jpg file
    cv2.imwrite('mask.jpg', cv2_image)
    
    # read the image using skimage
    mask = imread('mask.jpg')
    
    # resize the image
    #mask = resize(mask, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    
    # use np.expand dims to add a channel axis so the shape becomes (IMG_HEIGHT, IMG_WIDTH, 1)
    #mask = np.expand_dims(mask, axis=-1)
    
    # insert the image into X_Train
    X_train[i] = mask

    
    
# y_train

y_train = df_masks['num_cells'] #.astype(np.float16)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
# Out:
# (1190, 128, 128, 3)
# (1190,)
# (10, 128, 128, 3)

# %%
X_train[1, :, :, :].shape
# Out:
# (128, 128, 3)

# %% [markdown]
# ## Model Architecture

# %%
kernel_size = (3,3)
pool_size= (2,2)
first_filters = 32
second_filters = 64
third_filters = 128

dropout_conv = 0.3
dropout_dense = 0.3


model = Sequential()

# Input layer for rgb image. For grayscale image use the same channel 3 times
# to maintain the shape that the model requires.
model.add(Conv2D(first_filters, kernel_size, activation = 'relu', 
                 input_shape = (IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)))

model.add(ZeroPadding2D(padding=(PADDING, PADDING), data_format=None))

model.add(Conv2D(first_filters, kernel_size, activation = 'relu'))
model.add(Conv2D(first_filters, kernel_size, activation = 'relu'))
model.add(MaxPooling2D(pool_size = pool_size)) 
model.add(Dropout(dropout_conv))

model.add(Conv2D(second_filters, kernel_size, activation ='relu'))
model.add(Conv2D(second_filters, kernel_size, activation ='relu'))
model.add(Conv2D(second_filters, kernel_size, activation ='relu'))
model.add(MaxPooling2D(pool_size = pool_size))
model.add(Dropout(dropout_conv))

model.add(Conv2D(third_filters, kernel_size, activation ='relu'))
model.add(Conv2D(third_filters, kernel_size, activation ='relu'))
model.add(Conv2D(third_filters, kernel_size, activation ='relu'))
model.add(MaxPooling2D(pool_size = pool_size))
model.add(Dropout(dropout_conv))

model.add(Conv2D(third_filters, kernel_size, activation ='relu'))
model.add(Conv2D(third_filters, kernel_size, activation ='relu'))
model.add(Conv2D(third_filters, kernel_size, activation ='relu'))
model.add(MaxPooling2D(pool_size = pool_size))
model.add(Dropout(dropout_conv))

model.add(Flatten())

model.add(Dense(1024))
model.add(LeakyReLU())
model.add(BatchNormalization())

model.add(Dense(512))
model.add(LeakyReLU())
model.add(BatchNormalization())

model.add(Dense(1, activation='relu')) # set activation='relu' to keep all values positive

model.summary()
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/keras/layers/core.py:143: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 126, 126, 32)      896
# _________________________________________________________________
# zero_padding2d (ZeroPadding2 (None, 206, 206, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 204, 204, 32)      9248
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 202, 202, 32)      9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 101, 101, 32)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 101, 101, 32)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 99, 99, 64)        18496
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 97, 97, 64)        36928
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 95, 95, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 47, 47, 64)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 45, 45, 128)       73856
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 43, 43, 128)       147584
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 41, 41, 128)       147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 20, 20, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 20, 20, 128)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 18, 18, 128)       147584
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 16, 16, 128)       147584
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 14, 14, 128)       147584
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6272)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              6423552
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 1024)              0
# _________________________________________________________________
# batch_normalization_v1 (Batc (None, 1024)              4096
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 512)               0
# _________________________________________________________________
# batch_normalization_v1_1 (Ba (None, 512)               2048
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 7,878,529
# Trainable params: 7,875,457
# Non-trainable params: 3,072
# _________________________________________________________________

# %% [markdown]
# ## Train the Model

# %%
model.compile(Adam(lr=0.001), loss='mean_squared_error', 
              metrics=['mse'])

filepath = "model.h5"

earlystopper = EarlyStopping(patience=15, verbose=1)

checkpoint = ModelCheckpoint(filepath, monitor='val_mean_squared_error', verbose=1, 
                             save_best_only=True, mode='min')

callbacks_list = [earlystopper, checkpoint]

history = model.fit(X_train, y_train, validation_split=0.1, batch_size=16, epochs=100, 
                    callbacks=callbacks_list)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/keras/utils/losses_utils.py:170: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 1071 samples, validate on 119 samples
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 1387.2873 - mean_squared_error: 1387.2872
# Epoch 00001: val_mean_squared_error improved from inf to 282151.03125, saving model to model.h5
# 1071/1071 [==============================] - 8s 7ms/sample - loss: 1379.4228 - mean_squared_error: 1379.4229 - val_loss: 282151.0523 - val_mean_squared_error: 282151.0312
# Epoch 2/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 609.0443 - mean_squared_error: 609.0444
# Epoch 00002: val_mean_squared_error improved from 282151.03125 to 44515.26562, saving model to model.h5
# 1071/1071 [==============================] - 4s 4ms/sample - loss: 612.5903 - mean_squared_error: 612.5905 - val_loss: 44515.2666 - val_mean_squared_error: 44515.2656
# Epoch 3/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 471.0082 - mean_squared_error: 471.0081
# Epoch 00003: val_mean_squared_error did not improve from 44515.26562
# 1071/1071 [==============================] - 4s 4ms/sample - loss: 468.0570 - mean_squared_error: 468.0569 - val_loss: 227213.6696 - val_mean_squared_error: 227213.6562
# Epoch 4/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 443.8748 - mean_squared_error: 443.8748
# Epoch 00004: val_mean_squared_error improved from 44515.26562 to 207.36719, saving model to model.h5
# 1071/1071 [==============================] - 4s 4ms/sample - loss: 441.2318 - mean_squared_error: 441.2318 - val_loss: 207.3672 - val_mean_squared_error: 207.3672
# Epoch 5/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 329.0999 - mean_squared_error: 329.0998
# Epoch 00005: val_mean_squared_error did not improve from 207.36719
# 1071/1071 [==============================] - 4s 3ms/sample - loss: 328.7411 - mean_squared_error: 328.7411 - val_loss: 3642.3529 - val_mean_squared_error: 3642.3530
# Epoch 6/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 225.7767 - mean_squared_error: 225.7767
# Epoch 00006: val_mean_squared_error improved from 207.36719 to 101.32110, saving model to model.h5
# 1071/1071 [==============================] - 4s 4ms/sample - loss: 225.9579 - mean_squared_error: 225.9579 - val_loss: 101.3211 - val_mean_squared_error: 101.3211
# Epoch 7/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 273.5582 - mean_squared_error: 273.5582
# Epoch 00007: val_mean_squared_error did not improve from 101.32110
# 1071/1071 [==============================] - 4s 3ms/sample - loss: 272.6718 - mean_squared_error: 272.6718 - val_loss: 8510.9027 - val_mean_squared_error: 8510.9033
# Epoch 8/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 226.0675 - mean_squared_error: 226.0676
# Epoch 00008: val_mean_squared_error did not improve from 101.32110
# 1071/1071 [==============================] - 4s 3ms/sample - loss: 232.7221 - mean_squared_error: 232.7221 - val_loss: 2087.7690 - val_mean_squared_error: 2087.7688
# Epoch 9/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 258.8031 - mean_squared_error: 258.8030
# Epoch 00009: val_mean_squared_error did not improve from 101.32110
# 1071/1071 [==============================] - 4s 3ms/sample - loss: 255.8127 - mean_squared_error: 255.8127 - val_loss: 4153.7893 - val_mean_squared_error: 4153.7896
# Epoch 10/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 157.1386 - mean_squared_error: 157.1386
# Epoch 00010: val_mean_squared_error did not improve from 101.32110
# 1071/1071 [==============================] - 4s 3ms/sample - loss: 156.9227 - mean_squared_error: 156.9227 - val_loss: 363.5439 - val_mean_squared_error: 363.5439
# Epoch 11/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 162.9655 - mean_squared_error: 162.9655
# Epoch 00011: val_mean_squared_error did not improve from 101.32110
# 1071/1071 [==============================] - 4s 3ms/sample - loss: 162.3960 - mean_squared_error: 162.3960 - val_loss: 503.4591 - val_mean_squared_error: 503.4591
# Epoch 12/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 185.4432 - mean_squared_error: 185.4432
# Epoch 00012: val_mean_squared_error did not improve from 101.32110
# 1071/1071 [==============================] - 4s 3ms/sample - loss: 188.6026 - mean_squared_error: 188.6026 - val_loss: 489.3971 - val_mean_squared_error: 489.3971
# Epoch 13/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 189.4562 - mean_squared_error: 189.4562
# Epoch 00013: val_mean_squared_error improved from 101.32110 to 82.23735, saving model to model.h5
# 1071/1071 [==============================] - 4s 4ms/sample - loss: 188.4096 - mean_squared_error: 188.4096 - val_loss: 82.2374 - val_mean_squared_error: 82.2374
# Epoch 14/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 164.2737 - mean_squared_error: 164.2737
# Epoch 00014: val_mean_squared_error did not improve from 82.23735
# 1071/1071 [==============================] - 4s 3ms/sample - loss: 163.9392 - mean_squared_error: 163.9392 - val_loss: 652.8700 - val_mean_squared_error: 652.8699
# Epoch 15/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 143.7241 - mean_squared_error: 143.7241
# Epoch 00015: val_mean_squared_error did not improve from 82.23735
# 1071/1071 [==============================] - 4s 3ms/sample - loss: 142.5121 - mean_squared_error: 142.5121 - val_loss: 539.3271 - val_mean_squared_error: 539.3271
# Epoch 16/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 128.6179 - mean_squared_error: 128.6179
# Epoch 00016: val_mean_squared_error did not improve from 82.23735
# 1071/1071 [==============================] - 4s 3ms/sample - loss: 127.6717 - mean_squared_error: 127.6717 - val_loss: 1052.6454 - val_mean_squared_error: 1052.6454
# Epoch 17/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 120.6005 - mean_squared_error: 120.6005
# Epoch 00017: val_mean_squared_error did not improve from 82.23735
# 1071/1071 [==============================] - 4s 3ms/sample - loss: 120.2003 - mean_squared_error: 120.2003 - val_loss: 7997.7228 - val_mean_squared_error: 7997.7227
# Epoch 18/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 115.8550 - mean_squared_error: 115.8550
# Epoch 00018: val_mean_squared_error did not improve from 82.23735
# 1071/1071 [==============================] - 4s 3ms/sample - loss: 115.0040 - mean_squared_error: 115.0039 - val_loss: 331.5958 - val_mean_squared_error: 331.5958
# Epoch 19/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 97.3477 - mean_squared_error: 97.3477
# Epoch 00019: val_mean_squared_error did not improve from 82.23735
# 1071/1071 [==============================] - 4s 3ms/sample - loss: 97.4543 - mean_squared_error: 97.4543 - val_loss: 324.4500 - val_mean_squared_error: 324.4500
# Epoch 20/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 129.8284 - mean_squared_error: 129.8284
# Epoch 00020: val_mean_squared_error did not improve from 82.23735
# 1071/1071 [==============================] - 4s 3ms/sample - loss: 129.8568 - mean_squared_error: 129.8568 - val_loss: 281.7633 - val_mean_squared_error: 281.7633
# Epoch 21/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 100.9824 - mean_squared_error: 100.9824
# Epoch 00021: val_mean_squared_error did not improve from 82.23735
# 1071/1071 [==============================] - 4s 3ms/sample - loss: 101.3563 - mean_squared_error: 101.3563 - val_loss: 1932.6019 - val_mean_squared_error: 1932.6018
# Epoch 22/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 105.5530 - mean_squared_error: 105.5530
# Epoch 00022: val_mean_squared_error improved from 82.23735 to 51.99268, saving model to model.h5
# 1071/1071 [==============================] - 4s 4ms/sample - loss: 104.5675 - mean_squared_error: 104.5675 - val_loss: 51.9927 - val_mean_squared_error: 51.9927
# Epoch 23/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 78.3373 - mean_squared_error: 78.3373
# Epoch 00023: val_mean_squared_error did not improve from 51.99268
# 1071/1071 [==============================] - 4s 3ms/sample - loss: 78.7694 - mean_squared_error: 78.7694 - val_loss: 876.0662 - val_mean_squared_error: 876.0662
# Epoch 24/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 90.1796 - mean_squared_error: 90.1796
# Epoch 00024: val_mean_squared_error did not improve from 51.99268
# 1071/1071 [==============================] - 4s 3ms/sample - loss: 90.8444 - mean_squared_error: 90.8444 - val_loss: 383.9871 - val_mean_squared_error: 383.9871
# Epoch 25/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 81.9950 - mean_squared_error: 81.9950
# Epoch 00025: val_mean_squared_error did not improve from 51.99268
# 1071/1071 [==============================] - 4s 3ms/sample - loss: 81.3002 - mean_squared_error: 81.3002 - val_loss: 767.7877 - val_mean_squared_error: 767.7877
# Epoch 26/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 55.3653 - mean_squared_error: 55.3653
# Epoch 00026: val_mean_squared_error did not improve from 51.99268
# 1071/1071 [==============================] - 4s 3ms/sample - loss: 55.6290 - mean_squared_error: 55.6290 - val_loss: 639.6207 - val_mean_squared_error: 639.6208
# Epoch 27/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 62.2427 - mean_squared_error: 62.2427
# Epoch 00027: val_mean_squared_error improved from 51.99268 to 16.95159, saving model to model.h5
# 1071/1071 [==============================] - 4s 4ms/sample - loss: 64.7817 - mean_squared_error: 64.7817 - val_loss: 16.9516 - val_mean_squared_error: 16.9516
# Epoch 28/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 63.5560 - mean_squared_error: 63.5560
# Epoch 00028: val_mean_squared_error did not improve from 16.95159
# 1071/1071 [==============================] - 4s 3ms/sample - loss: 62.9096 - mean_squared_error: 62.9096 - val_loss: 138.4822 - val_mean_squared_error: 138.4822
# Epoch 29/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 71.1053 - mean_squared_error: 71.1053
# Epoch 00029: val_mean_squared_error did not improve from 16.95159
# 1071/1071 [==============================] - 4s 4ms/sample - loss: 72.0329 - mean_squared_error: 72.0329 - val_loss: 618.6759 - val_mean_squared_error: 618.6760
# Epoch 30/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 78.7834 - mean_squared_error: 78.7835
# Epoch 00030: val_mean_squared_error did not improve from 16.95159
# 1071/1071 [==============================] - 4s 3ms/sample - loss: 78.1533 - mean_squared_error: 78.1533 - val_loss: 23.6603 - val_mean_squared_error: 23.6603
# Epoch 31/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 62.9496 - mean_squared_error: 62.9496
# Epoch 00031: val_mean_squared_error did not improve from 16.95159
# 1071/1071 [==============================] - 4s 3ms/sample - loss: 64.3775 - mean_squared_error: 64.3775 - val_loss: 40.3998 - val_mean_squared_error: 40.3998
# Epoch 32/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 70.8711 - mean_squared_error: 70.8711
# Epoch 00032: val_mean_squared_error did not improve from 16.95159
# 1071/1071 [==============================] - 4s 3ms/sample - loss: 70.1709 - mean_squared_error: 70.1709 - val_loss: 37.4737 - val_mean_squared_error: 37.4737
# Epoch 33/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 76.4376 - mean_squared_error: 76.4376
# Epoch 00033: val_mean_squared_error did not improve from 16.95159
# 1071/1071 [==============================] - 4s 3ms/sample - loss: 76.2597 - mean_squared_error: 76.2597 - val_loss: 156.9275 - val_mean_squared_error: 156.9275
# Epoch 34/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 61.6166 - mean_squared_error: 61.6166
# Epoch 00034: val_mean_squared_error improved from 16.95159 to 11.61147, saving model to model.h5
# 1071/1071 [==============================] - 4s 4ms/sample - loss: 61.0588 - mean_squared_error: 61.0588 - val_loss: 11.6115 - val_mean_squared_error: 11.6115
# Epoch 35/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 57.9870 - mean_squared_error: 57.9870
# Epoch 00035: val_mean_squared_error did not improve from 11.61147
# 1071/1071 [==============================] - 4s 3ms/sample - loss: 57.3918 - mean_squared_error: 57.3918 - val_loss: 20.6770 - val_mean_squared_error: 20.6770
# Epoch 36/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 61.1260 - mean_squared_error: 61.1260
# Epoch 00036: val_mean_squared_error did not improve from 11.61147
# 1071/1071 [==============================] - 4s 4ms/sample - loss: 62.2003 - mean_squared_error: 62.2003 - val_loss: 111.3472 - val_mean_squared_error: 111.3472
# Epoch 37/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 55.6069 - mean_squared_error: 55.6069
# Epoch 00037: val_mean_squared_error did not improve from 11.61147
# 1071/1071 [==============================] - 4s 3ms/sample - loss: 56.0327 - mean_squared_error: 56.0327 - val_loss: 258.8867 - val_mean_squared_error: 258.8867
# Epoch 38/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 69.2897 - mean_squared_error: 69.2897
# Epoch 00038: val_mean_squared_error did not improve from 11.61147
# 1071/1071 [==============================] - 4s 3ms/sample - loss: 69.4124 - mean_squared_error: 69.4125 - val_loss: 138.4389 - val_mean_squared_error: 138.4389
# Epoch 39/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 75.5635 - mean_squared_error: 75.5635
# Epoch 00039: val_mean_squared_error did not improve from 11.61147
# 1071/1071 [==============================] - 4s 3ms/sample - loss: 76.1877 - mean_squared_error: 76.1877 - val_loss: 17.0901 - val_mean_squared_error: 17.0901
# Epoch 40/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 69.8639 - mean_squared_error: 69.8639
# Epoch 00040: val_mean_squared_error did not improve from 11.61147
# 1071/1071 [==============================] - 4s 3ms/sample - loss: 73.6261 - mean_squared_error: 73.6261 - val_loss: 725.3120 - val_mean_squared_error: 725.3120
# Epoch 41/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 77.8483 - mean_squared_error: 77.8483
# Epoch 00041: val_mean_squared_error did not improve from 11.61147
# 1071/1071 [==============================] - 4s 3ms/sample - loss: 77.6381 - mean_squared_error: 77.6381 - val_loss: 22.4206 - val_mean_squared_error: 22.4206
# Epoch 42/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 56.3018 - mean_squared_error: 56.3018
# Epoch 00042: val_mean_squared_error did not improve from 11.61147
# 1071/1071 [==============================] - 4s 3ms/sample - loss: 56.2402 - mean_squared_error: 56.2401 - val_loss: 45.2428 - val_mean_squared_error: 45.2428
# Epoch 43/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 60.4600 - mean_squared_error: 60.4600
# Epoch 00043: val_mean_squared_error did not improve from 11.61147
# 1071/1071 [==============================] - 4s 3ms/sample - loss: 60.0052 - mean_squared_error: 60.0052 - val_loss: 56.7128 - val_mean_squared_error: 56.7128
# Epoch 44/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 67.5721 - mean_squared_error: 67.5721
# Epoch 00044: val_mean_squared_error did not improve from 11.61147
# 1071/1071 [==============================] - 4s 3ms/sample - loss: 66.7986 - mean_squared_error: 66.7986 - val_loss: 28.0606 - val_mean_squared_error: 28.0606
# Epoch 45/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 60.0140 - mean_squared_error: 60.0140
# Epoch 00045: val_mean_squared_error did not improve from 11.61147
# 1071/1071 [==============================] - 4s 3ms/sample - loss: 60.3964 - mean_squared_error: 60.3964 - val_loss: 105.0961 - val_mean_squared_error: 105.0961
# Epoch 46/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 64.5290 - mean_squared_error: 64.5291
# Epoch 00046: val_mean_squared_error did not improve from 11.61147
# 1071/1071 [==============================] - 4s 3ms/sample - loss: 63.9844 - mean_squared_error: 63.9845 - val_loss: 98.4150 - val_mean_squared_error: 98.4150
# Epoch 47/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 70.1870 - mean_squared_error: 70.1870
# Epoch 00047: val_mean_squared_error improved from 11.61147 to 9.50419, saving model to model.h5
# 1071/1071 [==============================] - 4s 4ms/sample - loss: 69.5099 - mean_squared_error: 69.5098 - val_loss: 9.5042 - val_mean_squared_error: 9.5042
# Epoch 48/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 64.4822 - mean_squared_error: 64.4822
# Epoch 00048: val_mean_squared_error did not improve from 9.50419
# 1071/1071 [==============================] - 4s 3ms/sample - loss: 63.8558 - mean_squared_error: 63.8558 - val_loss: 81.3264 - val_mean_squared_error: 81.3264
# Epoch 49/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 59.5500 - mean_squared_error: 59.5500
# Epoch 00049: val_mean_squared_error did not improve from 9.50419
# 1071/1071 [==============================] - 4s 4ms/sample - loss: 62.5358 - mean_squared_error: 62.5358 - val_loss: 14.6465 - val_mean_squared_error: 14.6465
# Epoch 50/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 60.6227 - mean_squared_error: 60.6227
# Epoch 00050: val_mean_squared_error did not improve from 9.50419
# 1071/1071 [==============================] - 4s 3ms/sample - loss: 60.0221 - mean_squared_error: 60.0221 - val_loss: 28.1163 - val_mean_squared_error: 28.1163
# Epoch 51/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 67.4956 - mean_squared_error: 67.4956
# Epoch 00051: val_mean_squared_error improved from 9.50419 to 8.89717, saving model to model.h5
# 1071/1071 [==============================] - 4s 4ms/sample - loss: 66.7058 - mean_squared_error: 66.7058 - val_loss: 8.8972 - val_mean_squared_error: 8.8972
# Epoch 52/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 65.7512 - mean_squared_error: 65.7512
# Epoch 00052: val_mean_squared_error did not improve from 8.89717
# 1071/1071 [==============================] - 4s 3ms/sample - loss: 65.0812 - mean_squared_error: 65.0812 - val_loss: 25.5265 - val_mean_squared_error: 25.5265
# Epoch 53/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 63.2352 - mean_squared_error: 63.2352
# Epoch 00053: val_mean_squared_error did not improve from 8.89717
# 1071/1071 [==============================] - 4s 4ms/sample - loss: 63.0772 - mean_squared_error: 63.0772 - val_loss: 77.1936 - val_mean_squared_error: 77.1936
# Epoch 54/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 65.9714 - mean_squared_error: 65.9714
# Epoch 00054: val_mean_squared_error did not improve from 8.89717
# 1071/1071 [==============================] - 4s 3ms/sample - loss: 70.0566 - mean_squared_error: 70.0566 - val_loss: 336.4254 - val_mean_squared_error: 336.4254
# Epoch 55/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 76.4912 - mean_squared_error: 76.4912
# Epoch 00055: val_mean_squared_error did not improve from 8.89717
# 1071/1071 [==============================] - 4s 3ms/sample - loss: 81.4740 - mean_squared_error: 81.4740 - val_loss: 1605.9316 - val_mean_squared_error: 1605.9316
# Epoch 56/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 63.8227 - mean_squared_error: 63.8227
# Epoch 00056: val_mean_squared_error did not improve from 8.89717
# 1071/1071 [==============================] - 4s 3ms/sample - loss: 63.4635 - mean_squared_error: 63.4635 - val_loss: 911.6140 - val_mean_squared_error: 911.6141
# Epoch 57/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 58.3618 - mean_squared_error: 58.3618
# Epoch 00057: val_mean_squared_error did not improve from 8.89717
# 1071/1071 [==============================] - 4s 3ms/sample - loss: 58.3634 - mean_squared_error: 58.3634 - val_loss: 163.1466 - val_mean_squared_error: 163.1466
# Epoch 58/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 72.6258 - mean_squared_error: 72.6258
# Epoch 00058: val_mean_squared_error did not improve from 8.89717
# 1071/1071 [==============================] - 4s 3ms/sample - loss: 72.4516 - mean_squared_error: 72.4516 - val_loss: 39.1267 - val_mean_squared_error: 39.1267
# Epoch 59/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 66.4531 - mean_squared_error: 66.4531
# Epoch 00059: val_mean_squared_error did not improve from 8.89717
# 1071/1071 [==============================] - 4s 3ms/sample - loss: 65.7573 - mean_squared_error: 65.7573 - val_loss: 39.9680 - val_mean_squared_error: 39.9680
# Epoch 60/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 72.1219 - mean_squared_error: 72.1219
# Epoch 00060: val_mean_squared_error did not improve from 8.89717
# 1071/1071 [==============================] - 4s 3ms/sample - loss: 71.3877 - mean_squared_error: 71.3877 - val_loss: 97.4229 - val_mean_squared_error: 97.4229
# Epoch 61/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 69.3971 - mean_squared_error: 69.3971
# Epoch 00061: val_mean_squared_error did not improve from 8.89717
# 1071/1071 [==============================] - 4s 3ms/sample - loss: 69.4368 - mean_squared_error: 69.4368 - val_loss: 9.2981 - val_mean_squared_error: 9.2981
# Epoch 62/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 54.1150 - mean_squared_error: 54.1150
# Epoch 00062: val_mean_squared_error did not improve from 8.89717
# 1071/1071 [==============================] - 4s 3ms/sample - loss: 54.0474 - mean_squared_error: 54.0474 - val_loss: 338.6972 - val_mean_squared_error: 338.6972
# Epoch 63/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 55.9740 - mean_squared_error: 55.9741
# Epoch 00063: val_mean_squared_error did not improve from 8.89717
# 1071/1071 [==============================] - 4s 3ms/sample - loss: 58.8170 - mean_squared_error: 58.8170 - val_loss: 36.3821 - val_mean_squared_error: 36.3821
# Epoch 64/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 53.6250 - mean_squared_error: 53.6250
# Epoch 00064: val_mean_squared_error did not improve from 8.89717
# 1071/1071 [==============================] - 4s 3ms/sample - loss: 54.0237 - mean_squared_error: 54.0237 - val_loss: 13.3759 - val_mean_squared_error: 13.3759
# Epoch 65/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 59.8524 - mean_squared_error: 59.8524
# Epoch 00065: val_mean_squared_error did not improve from 8.89717
# 1071/1071 [==============================] - 4s 3ms/sample - loss: 59.3701 - mean_squared_error: 59.3701 - val_loss: 9.4203 - val_mean_squared_error: 9.4203
# Epoch 66/100
# 1056/1071 [============================>.] - ETA: 0s - loss: 59.8730 - mean_squared_error: 59.8730
# Epoch 00066: val_mean_squared_error did not improve from 8.89717
# 1071/1071 [==============================] - 4s 3ms/sample - loss: 59.8972 - mean_squared_error: 59.8972 - val_loss: 18.0940 - val_mean_squared_error: 18.0940
# Epoch 00066: early stopping

# %% [markdown]
# ## Plot the Training Curves

# %%
# display the loss and accuracy curves

import matplotlib.pyplot as plt

mean_squared_error = history.history['mean_squared_error']
val_mean_squared_error = history.history['val_mean_squared_error']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(mean_squared_error) + 1)

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.figure()

plt.plot(epochs, mean_squared_error, 'bo', label='Training mse')
plt.plot(epochs, val_mean_squared_error, 'b', label='Validation mse')
plt.title('Training and validation mse')
plt.legend()
plt.figure()

# %% [markdown]
# ## Make a Prediction

# %%
# use the best epoch
model.load_weights('model.h5')

preds = model.predict(X_test)

# %%
preds
# Out:
# array([[60.564438],
#        [86.316444],
#        [ 0.      ],
#        [11.876663],
#        [73.72762 ],
#        [10.872215],
#        [71.2686  ],
#        [50.917355],
#        [28.821377],
#        [80.81547 ]], dtype=float32)

# %% [markdown]
# ### What were the max and min errors?

# %%
# add the preds to df_test
df_test['preds'] = np.round(preds)

# change the preds to integers to improve the look of the displayed results
df_test['preds'] = df_test['preds'].apply(np.int)

# create a dataframe caled df_results
df_results = df_test[['mask_id', 'num_cells', 'preds']]

# add a new column with the difference between the true and predicted values.
df_results['difference'] = abs(df_results['num_cells'] - df_results['preds'])

# %%
df_results.head(10)
# Out:
#                               mask_id  num_cells  preds  difference
# 0  SIMCEPImages_A15_C61_F1_s03_w2.TIF         61     61           0
# 1  SIMCEPImages_A21_C87_F1_s03_w1.TIF         87     86           1
# 2   SIMCEPImages_A01_C1_F1_s02_w1.TIF          1      0           1
# 3  SIMCEPImages_A04_C14_F1_s05_w1.TIF         14     12           2
# 4  SIMCEPImages_A18_C74_F1_s01_w1.TIF         74     74           0
# 5  SIMCEPImages_A04_C14_F1_s18_w1.TIF         14     11           3
# 6  SIMCEPImages_A18_C74_F1_s09_w2.TIF         74     71           3
# 7  SIMCEPImages_A13_C53_F1_s10_w2.TIF         53     51           2
# 8  SIMCEPImages_A08_C31_F1_s13_w2.TIF         31     29           2
# 9  SIMCEPImages_A19_C78_F1_s15_w2.TIF         78     81           3

# %%
# What was the max difference?

max_diff = df_results['difference'].max()
min_diff = df_results['difference'].min()

print('Max Error: ', max_diff)
print('Min Error: ', min_diff)
# Out:
# Max Error:  3
# Min Error:  0

# %% [markdown]
# ## Display the Results

# %%
# =====================    
# Display the masks
# =====================  

# set up the canvas for the subplots
plt.figure(figsize=(10,10))
plt.axis('Off')

# Our subplot will contain 3 rows and 3 columns
# plt.subplot(nrows, ncols, plot_number)


# == row 1 ==

# image
plt.subplot(3,3,1)
test_image = X_test[1, :, :, 0]
plt.imshow(test_image)

true = df_results.loc[1, 'num_cells']
pred = df_results.loc[1, 'preds']
result = 'True: ' + str(true) + ' Pred: ' + str(pred)

plt.title(result, fontsize=14)
plt.axis('off')

# image
plt.subplot(3,3,2)
test_image = X_test[2, :, :, 0]
plt.imshow(test_image)

true = df_results.loc[2, 'num_cells']
pred = df_results.loc[2, 'preds']
result = 'True: ' + str(true) + ' Pred: ' + str(pred)

plt.title(result, fontsize=14)
plt.axis('off')


# image
plt.subplot(3,3,3)
test_image = X_test[3, :, :, 0]
plt.imshow(test_image)

true = df_results.loc[3, 'num_cells']
pred = df_results.loc[3, 'preds']
result = 'True: ' + str(true) + ' Pred: ' + str(pred)

plt.title(result, fontsize=14)
plt.axis('off')


# == row 2 ==

# image
plt.subplot(3,3,4)
test_image = X_test[4, :, :, 0]
plt.imshow(test_image)

true = df_results.loc[4, 'num_cells']
pred = df_results.loc[4, 'preds']
result = 'True: ' + str(true) + ' Pred: ' + str(pred)

plt.title(result, fontsize=14)
plt.axis('off')

# image
plt.subplot(3,3,5)
test_image = X_test[5, :, :, 0]
plt.imshow(test_image)

true = df_results.loc[5, 'num_cells']
pred = df_results.loc[5, 'preds']
result = 'True: ' + str(true) + ' Pred: ' + str(pred)

plt.title(result, fontsize=14)
plt.axis('off')

# image
plt.subplot(3,3,6)
test_image = X_test[6, :, :, 0]
plt.imshow(test_image)

true = df_results.loc[6, 'num_cells']
pred = df_results.loc[6, 'preds']
result = 'True: ' + str(true) + ' Pred: ' + str(pred)

plt.title(result, fontsize=14)
plt.axis('off')


# == row 3 ==

# image
plt.subplot(3,3,7)
test_image = X_test[7, :, :, 0]
plt.imshow(test_image)

true = df_results.loc[7, 'num_cells']
pred = df_results.loc[7, 'preds']
result = 'True: ' + str(true) + ' Pred: ' + str(pred)

plt.title(result, fontsize=14)
plt.axis('off')

# image
plt.subplot(3,3,8)
test_image = X_test[8, :, :, 0]
plt.imshow(test_image)

true = df_results.loc[8, 'num_cells']
pred = df_results.loc[8, 'preds']
result = 'True: ' + str(true) + ' Pred: ' + str(pred)

plt.title(result, fontsize=14)
plt.axis('off')

# image
plt.subplot(3,3,9)
test_image = X_test[9, :, :, 0]
plt.imshow(test_image)

true = df_results.loc[9, 'num_cells']
pred = df_results.loc[9, 'preds']
result = 'True: ' + str(true) + ' Pred: ' + str(pred)

plt.title(result, fontsize=14)
plt.axis('off')


plt.tight_layout()
plt.show()

# %% [markdown]
# ## Convert the Model to Tensorflow.js

# %%
# --ignore-installed is added to fix an error.

# https://stackoverflow.com/questions/49932759/pip-10-and-apt-how-to-avoid-cannot-uninstall
# -x-errors-for-distutils-packages

# !pip install tensorflowjs --ignore-installed
# Out:
# Collecting tensorflowjs
#   Downloading https://files.pythonhosted.org/packages/2e/95/c93699c03b532cdfe9d12bf36378efa300d94afeeebaee1883370cc7df79/tensorflowjs-1.1.2-py3-none-any.whl
# Collecting h5py==2.8.0 (from tensorflowjs)
#   Downloading https://files.pythonhosted.org/packages/8e/cb/726134109e7bd71d98d1fcc717ffe051767aac42ede0e7326fd1787e5d64/h5py-2.8.0-cp36-cp36m-manylinux1_x86_64.whl (2.8MB)
#     100% |████████████████████████████████| 2.8MB 10.3MB/s
# Collecting tensorflow-hub==0.3.0 (from tensorflowjs)
#   Downloading https://files.pythonhosted.org/packages/9e/f0/3a3ced04c8359e562f1b91918d9bde797c8a916fcfeddc8dc5d673d1be20/tensorflow_hub-0.3.0-py2.py3-none-any.whl (73kB)
#     100% |████████████████████████████████| 81kB 20.2MB/s
# Collecting tf-nightly-2.0-preview>=2.0.0.dev20190502 (from tensorflowjs)
#   Downloading https://files.pythonhosted.org/packages/5f/8c/c1818d0fd5675902e0915bdbbac42f145e112561c0088324d27d26426e95/tf_nightly_2.0_preview-2.0.0.dev20190603-cp36-cp36m-manylinux1_x86_64.whl (88.1MB)
#     100% |████████████████████████████████| 88.1MB 503kB/s
# Collecting numpy==1.15.1 (from tensorflowjs)
#   Downloading https://files.pythonhosted.org/packages/fe/94/7049fed8373c52839c8cde619acaf2c9b83082b935e5aa8c0fa27a4a8bcc/numpy-1.15.1-cp36-cp36m-manylinux1_x86_64.whl (13.9MB)
#     100% |████████████████████████████████| 13.9MB 3.2MB/s
# Collecting six==1.11.0 (from tensorflowjs)
#   Downloading https://files.pythonhosted.org/packages/67/4b/141a581104b1f6397bfa78ac9d43d8ad29a7ca43ea90a2d863fe3056e86a/six-1.11.0-py2.py3-none-any.whl
# Collecting keras==2.2.4 (from tensorflowjs)
#   Downloading https://files.pythonhosted.org/packages/5e/10/aa32dad071ce52b5502266b5c659451cfd6ffcbf14e6c8c4f16c0ff5aaab/Keras-2.2.4-py2.py3-none-any.whl (312kB)
#     100% |████████████████████████████████| 317kB 21.1MB/s
# Collecting protobuf>=3.4.0 (from tensorflow-hub==0.3.0->tensorflowjs)
#   Downloading https://files.pythonhosted.org/packages/d2/fb/29de8d08967f0cce1bb10b39846d836b0f3bf6776ddc36aed7c73498ca7e/protobuf-3.8.0-cp36-cp36m-manylinux1_x86_64.whl (1.2MB)
#     100% |████████████████████████████████| 1.2MB 17.6MB/s
# Collecting keras-applications>=1.0.6 (from tf-nightly-2.0-preview>=2.0.0.dev20190502->tensorflowjs)
#   Downloading https://files.pythonhosted.org/packages/71/e3/19762fdfc62877ae9102edf6342d71b28fbfd9dea3d2f96a882ce099b03f/Keras_Applications-1.0.8-py3-none-any.whl (50kB)
#     100% |████████████████████████████████| 51kB 17.2MB/s
# Collecting gast>=0.2.0 (from tf-nightly-2.0-preview>=2.0.0.dev20190502->tensorflowjs)
#   Downloading https://files.pythonhosted.org/packages/4e/35/11749bf99b2d4e3cceb4d55ca22590b0d7c2c62b9de38ac4a4a7f4687421/gast-0.2.2.tar.gz
# Collecting tb-nightly<1.15.0a0,>=1.14.0a0 (from tf-nightly-2.0-preview>=2.0.0.dev20190502->tensorflowjs)
#   Downloading https://files.pythonhosted.org/packages/a4/96/571b875cd81dda9d5dfa1422a4f9d749e67c0a8d4f4f0b33a4e5f5f35e27/tb_nightly-1.14.0a20190603-py3-none-any.whl (3.1MB)
#     100% |████████████████████████████████| 3.1MB 9.0MB/s
# Collecting termcolor>=1.1.0 (from tf-nightly-2.0-preview>=2.0.0.dev20190502->tensorflowjs)
#   Downloading https://files.pythonhosted.org/packages/8a/48/a76be51647d0eb9f10e2a4511bf3ffb8cc1e6b14e9e4fab46173aa79f981/termcolor-1.1.0.tar.gz
# Collecting wrapt>=1.11.1 (from tf-nightly-2.0-preview>=2.0.0.dev20190502->tensorflowjs)
#   Downloading https://files.pythonhosted.org/packages/67/b2/0f71ca90b0ade7fad27e3d20327c996c6252a2ffe88f50a95bba7434eda9/wrapt-1.11.1.tar.gz
# Collecting google-pasta>=0.1.6 (from tf-nightly-2.0-preview>=2.0.0.dev20190502->tensorflowjs)
#   Downloading https://files.pythonhosted.org/packages/d0/33/376510eb8d6246f3c30545f416b2263eee461e40940c2a4413c711bdf62d/google_pasta-0.1.7-py3-none-any.whl (52kB)
#     100% |████████████████████████████████| 61kB 20.6MB/s
# Collecting absl-py>=0.7.0 (from tf-nightly-2.0-preview>=2.0.0.dev20190502->tensorflowjs)
#   Downloading https://files.pythonhosted.org/packages/da/3f/9b0355080b81b15ba6a9ffcf1f5ea39e307a2778b2f2dc8694724e8abd5b/absl-py-0.7.1.tar.gz (99kB)
#     100% |████████████████████████████████| 102kB 23.6MB/s
# Collecting grpcio>=1.8.6 (from tf-nightly-2.0-preview>=2.0.0.dev20190502->tensorflowjs)
#   Downloading https://files.pythonhosted.org/packages/99/83/18f374294bf34128a448ee2fae37651f943b0b5fa473b5b3aff262c15bf8/grpcio-1.21.1-cp36-cp36m-manylinux1_x86_64.whl (2.2MB)
#     100% |████████████████████████████████| 2.2MB 14.6MB/s
# Collecting wheel>=0.26 (from tf-nightly-2.0-preview>=2.0.0.dev20190502->tensorflowjs)
#   Downloading https://files.pythonhosted.org/packages/bb/10/44230dd6bf3563b8f227dbf344c908d412ad2ff48066476672f3a72e174e/wheel-0.33.4-py2.py3-none-any.whl
# Collecting astor>=0.6.0 (from tf-nightly-2.0-preview>=2.0.0.dev20190502->tensorflowjs)
#   Downloading https://files.pythonhosted.org/packages/d1/4f/950dfae467b384fc96bc6469de25d832534f6b4441033c39f914efd13418/astor-0.8.0-py2.py3-none-any.whl
# Collecting keras-preprocessing>=1.0.5 (from tf-nightly-2.0-preview>=2.0.0.dev20190502->tensorflowjs)
#   Downloading https://files.pythonhosted.org/packages/28/6a/8c1f62c37212d9fc441a7e26736df51ce6f0e38455816445471f10da4f0a/Keras_Preprocessing-1.1.0-py2.py3-none-any.whl (41kB)
#     100% |████████████████████████████████| 51kB 17.9MB/s
# Collecting tensorflow-estimator-2.0-preview (from tf-nightly-2.0-preview>=2.0.0.dev20190502->tensorflowjs)
#   Downloading https://files.pythonhosted.org/packages/c1/4d/2fefad091a5b52a7af4f74e40aab2b4f1d354f7ebccdb53cd396a312779d/tensorflow_estimator_2.0_preview-1.14.0.dev2019060300-py2.py3-none-any.whl (430kB)
#     100% |████████████████████████████████| 440kB 24.4MB/s
# Collecting pyyaml (from keras==2.2.4->tensorflowjs)
#   Downloading https://files.pythonhosted.org/packages/9f/2c/9417b5c774792634834e730932745bc09a7d36754ca00acf1ccd1ac2594d/PyYAML-5.1.tar.gz (274kB)
#     100% |████████████████████████████████| 276kB 24.8MB/s
# Collecting scipy>=0.14 (from keras==2.2.4->tensorflowjs)
#   Downloading https://files.pythonhosted.org/packages/72/4c/5f81e7264b0a7a8bd570810f48cd346ba36faedbd2ba255c873ad556de76/scipy-1.3.0-cp36-cp36m-manylinux1_x86_64.whl (25.2MB)
#     100% |████████████████████████████████| 25.2MB 1.7MB/s
# Collecting setuptools (from protobuf>=3.4.0->tensorflow-hub==0.3.0->tensorflowjs)
#   Downloading https://files.pythonhosted.org/packages/ec/51/f45cea425fd5cb0b0380f5b0f048ebc1da5b417e48d304838c02d6288a1e/setuptools-41.0.1-py2.py3-none-any.whl (575kB)
#     100% |████████████████████████████████| 583kB 5.8MB/s
# Collecting markdown>=2.6.8 (from tb-nightly<1.15.0a0,>=1.14.0a0->tf-nightly-2.0-preview>=2.0.0.dev20190502->tensorflowjs)
#   Downloading https://files.pythonhosted.org/packages/c0/4e/fd492e91abdc2d2fcb70ef453064d980688762079397f779758e055f6575/Markdown-3.1.1-py2.py3-none-any.whl (87kB)
#     100% |████████████████████████████████| 92kB 21.6MB/s
# Collecting werkzeug>=0.11.15 (from tb-nightly<1.15.0a0,>=1.14.0a0->tf-nightly-2.0-preview>=2.0.0.dev20190502->tensorflowjs)
#   Downloading https://files.pythonhosted.org/packages/9f/57/92a497e38161ce40606c27a86759c6b92dd34fcdb33f64171ec559257c02/Werkzeug-0.15.4-py2.py3-none-any.whl (327kB)
#     100% |████████████████████████████████| 327kB 23.9MB/s
# Building wheels for collected packages: gast, termcolor, wrapt, absl-py, pyyaml
# done
#   Stored in directory: /tmp/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# done
#   Stored in directory: /tmp/.cache/pip/wheels/7c/06/54/bc84598ba1daf8f970247f550b175aaaee85f68b4b0c5ab2c6
# done
#   Stored in directory: /tmp/.cache/pip/wheels/89/67/41/63cbf0f6ac0a6156588b9587be4db5565f8c6d8ccef98202fc
# done
#   Stored in directory: /tmp/.cache/pip/wheels/ee/98/38/46cbcc5a93cfea5492d19c38562691ddb23b940176c14f7b48
# done
#   Stored in directory: /tmp/.cache/pip/wheels/ad/56/bc/1522f864feb2a358ea6f1a92b4798d69ac783a28e80567a18b
# Successfully built gast termcolor wrapt absl-py pyyaml
# s3fs 0.2.1 has requirement six>=1.12.0, but you'll have six 1.11.0 which is incompatible.
# pytest-cov 2.6.1 has requirement pytest>=3.6, but you'll have pytest 3.5.1 which is incompatible.
# mxnet-cu100 1.4.0.post0 has requirement numpy<1.15.0,>=1.8.2, but you'll have numpy 1.15.1 which is incompatible.
# lime 0.1.1.33 has requirement matplotlib==2.1.0, but you'll have matplotlib 3.0.3 which is incompatible.
# kmeans-smote 0.1.2 has requirement imbalanced-learn<0.5,>=0.4.0, but you'll have imbalanced-learn 0.5.0.dev0 which is incompatible.
# anaconda-client 1.6.14 has requirement python-dateutil>=2.6.1, but you'll have python-dateutil 2.6.0 which is incompatible.
# Installing collected packages: numpy, six, h5py, setuptools, protobuf, tensorflow-hub, keras-applications, gast, grpcio, wheel, markdown, werkzeug, absl-py, tb-nightly, termcolor, wrapt, google-pasta, astor, keras-preprocessing, tensorflow-estimator-2.0-preview, tf-nightly-2.0-preview, pyyaml, scipy, keras, tensorflowjs
# Successfully installed absl-py-0.7.1 astor-0.8.0 gast-0.2.2 google-pasta-0.1.7 grpcio-1.21.1 h5py-2.9.0 keras-2.2.4 keras-applications-1.0.8 keras-preprocessing-1.1.0 markdown-3.1.1 numpy-1.16.3 protobuf-3.8.0 pyyaml-5.1 scipy-1.3.0 setuptools-41.0.1 six-1.12.0 tb-nightly-1.14.0a20190603 tensorflow-estimator-2.0-preview-1.14.0.dev2019060300 tensorflow-hub-0.4.0 tensorflowjs-1.1.2 termcolor-1.1.0 tf-nightly-2.0-preview-2.0.0.dev20190603 werkzeug-0.15.4 wheel-0.33.4 wrapt-1.11.1
# You are using pip version 19.0.3, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# Use the command line conversion tool to convert the model

# !tensorflowjs_converter --input_format keras model.h5 tfjs/model

# %%
# check that the folder containing the tfjs model files has been created
# !ls
# Out:
# __notebook__.ipynb  __output__.json  mask.jpg  model.h5  tfjs

# %% [markdown]
# ## Conclusion

# %% [markdown]
# We see that the results are unexpectedly good. Who would have thought that a simple cnn could perform this well. With only 1,190 training images it appears that it is in fact possible to build a cell counting model that produces good results.
#
# You will notice that the model has a padding layer. Padding the images helped to improve the model's performance. This could be because padding helped the model to detect cells that are located at the edges of the masks.
#
# Intuitively one would think that to improve the model's performance we need to add more images that look like paint splashes. Surprisingly, while doing different experiments, I saw that the model found it easier to analyze paint splash images and images with a large number of cells. It struggled a bit with images that showed a few individual cells. Therefore, one preliminary conclusion is that, in order to improve model performance, we need to add more images showing just a few individual cells (about 1 to 14 cells).
#
# It's important to take note that the results are different each time this kernel is run. This could be because Keras uses a different validation set each time. Therefore, it's advisable to perform 5 fold cross validation to get a more confident estimate of this models performance.
#
# Thank you for reading.
